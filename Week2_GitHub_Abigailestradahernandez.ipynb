# %% [markdown]
# <a href="https://colab.research.google.com/github/abigaile188/CSS_box_model/blob/main/Week2_GitHub_Abigailestradahernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python
CopyEdit
print("Hello,Github from collab")
